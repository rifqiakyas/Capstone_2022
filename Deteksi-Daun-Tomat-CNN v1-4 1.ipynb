# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2
import pathlib

# %%
import os
base_dir = 'C:\Sem 5\Studi Independen\Machine Learning\CapstoneProject\datasetBersih'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,           # normalisasi data                
                    ) 
test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=64,
                                                    target_size=(224, 224),
                                                    class_mode='categorical',
                                                    color_mode= 'rgb', 
                                                    shuffle= True
                                                    )
test_generator = test_datagen.flow_from_directory(validation_dir,
                                                  batch_size=64,
                                                  target_size=(224, 224),
                                                  class_mode='categorical',
                                                  color_mode= 'rgb', 
                                                  shuffle= True
                                                  )
# Out:
# Found 11110 images belonging to 11 classes.
# Found 2783 images belonging to 11 classes.

# %%
class_dict=train_generator.class_indices
classes=list(class_dict.keys())
print ('LIST OF CLASSES ', classes)
print ('CLASS DICTIONARY ',class_dict)
number_of_classes=len(classes) # this is the number of neurons in your top layer of the model
print ('Number of classes = ', number_of_classes)
# Out:
# LIST OF CLASSES  ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_Yellow_Leaf_Curl_Virus', 'Tomato_mosaic_virus', 'healthy', 'powdery_mildew']
# CLASS DICTIONARY  {'Bacterial_spot': 0, 'Early_blight': 1, 'Late_blight': 2, 'Leaf_Mold': 3, 'Septoria_leaf_spot': 4, 'Spider_mites Two-spotted_spider_mite': 5, 'Target_Spot': 6, 'Tomato_Yellow_Leaf_Curl_Virus': 7, 'Tomato_mosaic_virus': 8, 'healthy': 9, 'powdery_mildew': 10}
# Number of classes =  11

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),                           # 3 layer konvolusi
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),                                                      # layer input untuk deep learning neural network
    
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(11, activation= 'softmax')    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 4,817,995
# Trainable params: 4,817,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer ='Adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
class TestCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > 0.92 and logs.get('val_accuracy') > 0.92):
            print("\nAkurasi telah mencapai >90%!") 
            self.model.stop_training = True 
callbacks = TestCallback()

# %%
history=model.fit(
      train_generator,
      steps_per_epoch=4,                    
      epochs=50,                            
      validation_data=test_generator,       
      verbose=2,
      validation_steps=4,             
      callbacks = [callbacks]
      )
# Out:
# Epoch 1/50
# 4/4 - 10s - loss: 2.4118 - accuracy: 0.1094 - val_loss: 2.3836 - val_accuracy: 0.1055 - 10s/epoch - 2s/step
# Epoch 2/50
# 4/4 - 9s - loss: 2.3839 - accuracy: 0.1172 - val_loss: 2.3505 - val_accuracy: 0.1094 - 9s/epoch - 2s/step
# Epoch 3/50
# 4/4 - 9s - loss: 2.3269 - accuracy: 0.1367 - val_loss: 2.2623 - val_accuracy: 0.2734 - 9s/epoch - 2s/step
# Epoch 4/50
# 4/4 - 8s - loss: 2.2191 - accuracy: 0.2734 - val_loss: 2.1523 - val_accuracy: 0.2148 - 8s/epoch - 2s/step
# Epoch 5/50
# 4/4 - 8s - loss: 2.1167 - accuracy: 0.2344 - val_loss: 1.9110 - val_accuracy: 0.4336 - 8s/epoch - 2s/step
# Epoch 6/50
# 4/4 - 8s - loss: 1.9100 - accuracy: 0.4141 - val_loss: 1.9760 - val_accuracy: 0.2812 - 8s/epoch - 2s/step
# Epoch 7/50
# 4/4 - 8s - loss: 1.9443 - accuracy: 0.3164 - val_loss: 1.7781 - val_accuracy: 0.3516 - 8s/epoch - 2s/step
# Epoch 8/50
# 4/4 - 8s - loss: 1.7975 - accuracy: 0.3516 - val_loss: 1.8033 - val_accuracy: 0.3672 - 8s/epoch - 2s/step
# Epoch 9/50
# 4/4 - 8s - loss: 1.7145 - accuracy: 0.3984 - val_loss: 1.5967 - val_accuracy: 0.4492 - 8s/epoch - 2s/step
# Epoch 10/50
# 4/4 - 8s - loss: 1.6760 - accuracy: 0.3867 - val_loss: 1.5054 - val_accuracy: 0.4883 - 8s/epoch - 2s/step
# Epoch 11/50
# 4/4 - 9s - loss: 1.5411 - accuracy: 0.4531 - val_loss: 1.3378 - val_accuracy: 0.5156 - 9s/epoch - 2s/step
# Epoch 12/50
# 4/4 - 9s - loss: 1.5582 - accuracy: 0.4570 - val_loss: 1.4538 - val_accuracy: 0.4453 - 9s/epoch - 2s/step
# Epoch 13/50
# 4/4 - 9s - loss: 1.3025 - accuracy: 0.5586 - val_loss: 1.3768 - val_accuracy: 0.5000 - 9s/epoch - 2s/step
# Epoch 14/50
# 4/4 - 10s - loss: 1.2173 - accuracy: 0.5742 - val_loss: 1.3333 - val_accuracy: 0.5430 - 10s/epoch - 3s/step
# Epoch 15/50
# 4/4 - 10s - loss: 1.3193 - accuracy: 0.5547 - val_loss: 1.2822 - val_accuracy: 0.5508 - 10s/epoch - 2s/step
# Epoch 16/50
# 4/4 - 10s - loss: 1.3178 - accuracy: 0.5742 - val_loss: 1.2905 - val_accuracy: 0.5195 - 10s/epoch - 2s/step
# Epoch 17/50
# 4/4 - 10s - loss: 1.2941 - accuracy: 0.5195 - val_loss: 1.1740 - val_accuracy: 0.6172 - 10s/epoch - 2s/step
# Epoch 18/50
# 4/4 - 10s - loss: 1.1920 - accuracy: 0.5977 - val_loss: 1.3382 - val_accuracy: 0.5234 - 10s/epoch - 2s/step
# Epoch 19/50
# 4/4 - 10s - loss: 1.2725 - accuracy: 0.5391 - val_loss: 1.1608 - val_accuracy: 0.6094 - 10s/epoch - 2s/step
# Epoch 20/50
# 4/4 - 10s - loss: 1.1186 - accuracy: 0.6406 - val_loss: 1.1988 - val_accuracy: 0.5898 - 10s/epoch - 3s/step
# Epoch 21/50
# 4/4 - 10s - loss: 1.1175 - accuracy: 0.6094 - val_loss: 1.0433 - val_accuracy: 0.6367 - 10s/epoch - 3s/step
# Epoch 22/50
# 4/4 - 10s - loss: 0.8909 - accuracy: 0.6652 - val_loss: 1.1646 - val_accuracy: 0.6445 - 10s/epoch - 2s/step
# Epoch 23/50
# 4/4 - 10s - loss: 1.0513 - accuracy: 0.6523 - val_loss: 1.1036 - val_accuracy: 0.6328 - 10s/epoch - 2s/step
# Epoch 24/50
# 4/4 - 10s - loss: 1.1269 - accuracy: 0.6094 - val_loss: 1.1423 - val_accuracy: 0.6133 - 10s/epoch - 3s/step
# Epoch 25/50
# 4/4 - 8s - loss: 0.9329 - accuracy: 0.6758 - val_loss: 1.2004 - val_accuracy: 0.5938 - 8s/epoch - 2s/step
# Epoch 26/50
# 4/4 - 9s - loss: 1.0482 - accuracy: 0.6719 - val_loss: 1.0872 - val_accuracy: 0.6250 - 9s/epoch - 2s/step
# Epoch 27/50
# 4/4 - 8s - loss: 1.0903 - accuracy: 0.6406 - val_loss: 1.2245 - val_accuracy: 0.5664 - 8s/epoch - 2s/step
# Epoch 28/50
# 4/4 - 8s - loss: 1.0378 - accuracy: 0.6836 - val_loss: 0.9907 - val_accuracy: 0.6562 - 8s/epoch - 2s/step
# Epoch 29/50
# 4/4 - 8s - loss: 1.1011 - accuracy: 0.6484 - val_loss: 0.8945 - val_accuracy: 0.6719 - 8s/epoch - 2s/step
# Epoch 30/50
# 4/4 - 8s - loss: 0.9085 - accuracy: 0.6602 - val_loss: 0.9819 - val_accuracy: 0.6562 - 8s/epoch - 2s/step
# Epoch 31/50
# 4/4 - 8s - loss: 0.8660 - accuracy: 0.7031 - val_loss: 1.0487 - val_accuracy: 0.6328 - 8s/epoch - 2s/step
# Epoch 32/50
# 4/4 - 8s - loss: 1.0221 - accuracy: 0.6641 - val_loss: 1.1964 - val_accuracy: 0.6055 - 8s/epoch - 2s/step
# Epoch 33/50
# 4/4 - 8s - loss: 1.1588 - accuracy: 0.6172 - val_loss: 1.0194 - val_accuracy: 0.6523 - 8s/epoch - 2s/step
# Epoch 34/50
# 4/4 - 8s - loss: 0.9083 - accuracy: 0.6953 - val_loss: 1.1350 - val_accuracy: 0.5938 - 8s/epoch - 2s/step
# Epoch 35/50
# 4/4 - 8s - loss: 0.9282 - accuracy: 0.6875 - val_loss: 0.8691 - val_accuracy: 0.6875 - 8s/epoch - 2s/step
# Epoch 36/50
# 4/4 - 9s - loss: 0.8319 - accuracy: 0.7422 - val_loss: 1.0022 - val_accuracy: 0.6289 - 9s/epoch - 2s/step
# Epoch 37/50
# 4/4 - 10s - loss: 0.7548 - accuracy: 0.7188 - val_loss: 0.7181 - val_accuracy: 0.7695 - 10s/epoch - 2s/step
# Epoch 38/50
# 4/4 - 9s - loss: 0.8572 - accuracy: 0.6797 - val_loss: 0.8962 - val_accuracy: 0.7500 - 9s/epoch - 2s/step
# Epoch 39/50
# 4/4 - 9s - loss: 0.7931 - accuracy: 0.7109 - val_loss: 0.8109 - val_accuracy: 0.7148 - 9s/epoch - 2s/step
# Epoch 40/50
# 4/4 - 9s - loss: 0.7121 - accuracy: 0.7734 - val_loss: 0.8956 - val_accuracy: 0.7109 - 9s/epoch - 2s/step
# Epoch 41/50
# 4/4 - 8s - loss: 0.8167 - accuracy: 0.7188 - val_loss: 0.8685 - val_accuracy: 0.7109 - 8s/epoch - 2s/step
# Epoch 42/50
# 4/4 - 8s - loss: 0.7120 - accuracy: 0.7500 - val_loss: 0.8248 - val_accuracy: 0.6641 - 8s/epoch - 2s/step
# Epoch 43/50
# 4/4 - 8s - loss: 0.7182 - accuracy: 0.7695 - val_loss: 0.7318 - val_accuracy: 0.7539 - 8s/epoch - 2s/step
# Epoch 44/50
# 4/4 - 8s - loss: 0.7358 - accuracy: 0.7617 - val_loss: 0.8128 - val_accuracy: 0.7031 - 8s/epoch - 2s/step
# Epoch 45/50
# 4/4 - 8s - loss: 0.7448 - accuracy: 0.7695 - val_loss: 0.8224 - val_accuracy: 0.7070 - 8s/epoch - 2s/step
# Epoch 46/50
# 4/4 - 8s - loss: 0.7688 - accuracy: 0.7500 - val_loss: 0.6754 - val_accuracy: 0.7891 - 8s/epoch - 2s/step
# Epoch 47/50
# 4/4 - 8s - loss: 0.6897 - accuracy: 0.7422 - val_loss: 0.7309 - val_accuracy: 0.7383 - 8s/epoch - 2s/step
# Epoch 48/50
# 4/4 - 8s - loss: 0.7432 - accuracy: 0.7422 - val_loss: 0.6669 - val_accuracy: 0.7656 - 8s/epoch - 2s/step
# Epoch 49/50
# 4/4 - 8s - loss: 0.6155 - accuracy: 0.8008 - val_loss: 0.8369 - val_accuracy: 0.7422 - 8s/epoch - 2s/step
# Epoch 50/50
# 4/4 - 8s - loss: 0.7209 - accuracy: 0.7734 - val_loss: 0.8572 - val_accuracy: 0.6914 - 8s/epoch - 2s/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(test_generator)
# Out:
# 44/44 [==============================] - 16s 352ms/step

# %%
from sklearn.metrics import confusion_matrix , classification_report
import numpy as np
y_pred_classes = [np.argmax(element) for element in y_pred]
classification_report(test_generator,y_pred_classes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22132\1632483156.py in <module>
#       2 import numpy as np
#       3 y_pred_classes = [np.argmax(element) for element in y_pred]
# ----> 4 classification_report(test_generator,y_pred_classes)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2108     """
#    2109
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2111
#    2112     if labels is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [44, 2783]
