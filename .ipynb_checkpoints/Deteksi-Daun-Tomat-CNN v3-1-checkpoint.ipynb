# %% [markdown]
# # Leaf Septoria Detection using CNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import pathlib
import os

# %%
import os
base_dir = 'C:\Sem 5\Studi Independen\Machine Learning\CapstoneProject\datasetBersih'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')
# Out:
# Mounted at /content/drive

# %%
# After loading the drive, copy the path of your train & validation data
train_path = '/content/drive/MyDrive/Tomato disease/train'
val_path = '/content/drive/MyDrive/Tomato disease/valid'

# %%
# Custom function to plot the image
# plot the image
def imshow(img_arr):
    # We want to display multiple images in a single row,
    # Thus, we use subplots
    fig, axes = plt.subplots(1, 5, figsize=(10,10))

    axes = axes.flatten()

    for img, ax in zip(img_arr, axes):
        ax.imshow(img)
        
    plt.show()

# %%
# Augmentation of the images 
# using keras.ImageDataGenerator

train_aug = ImageDataGenerator(
    rescale = 1/255,   # Divide the pixel values by 255 to narmalize them
    rotation_range = 30,          # Rotate
    width_shift_range = 0.1,      # shift through the width
    height_shift_range = 0.1,     # shift through the height
    shear_range = 0.1,            # apply shear on the image
    horizontal_flip = True,       # Flip horizontally
    vertical_flip = True,         # Flip vertically
    fill_mode = 'nearest',        # To fill up the pixels cut off during augmentation
    brightness_range = [0.7,1.4]  # To introduce different lighting conditions
)

train_data = train_aug.flow_from_directory(train_path, 
                                           target_size = (150,150),   #Reduce shape of images to 150 X 150
                                           batch_size=32,             # Take 32 images at once and do it on them
                                           class_mode = 'binary')
# Out:
# Found 3047 images belonging to 2 classes.

# %%
# We repeat the above process for the validation set also
# But bacause it is the validation set, we apply less augmentation
# Do less augmentation for validation data
valid_aug = ImageDataGenerator(rescale = 1/255, rotation_range = 40)

# We used rotation to add just 
# a little more augmentation 
# to get more images for our validation set

valid_data = valid_aug.flow_from_directory(val_path,
                                           target_size = (150,150),
                                           batch_size = 32,
                                           class_mode = 'binary'
                                           )
# Out:
# Found 400 images belonging to 2 classes.

# %%
print(train_data.class_indices)
print(valid_data.class_indices)
# Out:
# {'healthy_leaf': 0, 'septoria_leaf': 1}
# {'healthy_leaf': 0, 'septoria_leaf': 1}

# %%
imshow(train_data[0][0][0] for i in range(5))
imshow(train_data[0][0][5] for i in range(5))

# %%
# Just to check if the dataset is balanced or not
y = train_data.classes
count_septoria, count_healthy = 0,0

for x in y:
    if x==0:
        count_healthy += 1
    else:
        count_septoria += 1
print("Septoria:",count_septoria,"   Healthy:",count_healthy)
# Out:
# Septoria: 1571    Healthy: 1476

# %% [markdown]
# # Building the CNN

# %%
cnn = keras.models.Sequential()
# 3 Convolution and 3 Max Pool layers
cnn.add(layers.Conv2D( filters=32, kernel_size=(4,4), activation='relu', input_shape = [150,150,3] ))
cnn.add(layers.MaxPooling2D( pool_size=(2,2)))

cnn.add(layers.Conv2D( filters=64, kernel_size=(4,4), activation='relu' ))
cnn.add(layers.MaxPooling2D( pool_size = (2,2) ))

cnn.add(layers.Conv2D( filters=128, kernel_size=(4,4), activation='relu' ))
cnn.add(layers.MaxPooling2D( pool_size = (2,2) ))

# Dense Layer with Dropout
cnn.add(layers.Dropout(0.4))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(units=128, activation = 'relu'))

# Hidden Layer
cnn.add(layers.Dropout(0.15))
cnn.add(layers.Dense(units=256, activation = 'relu'))

# Output layer
cnn.add(layers.Dropout(0.25))
cnn.add(layers.Dense(units=1, activation = 'sigmoid'))

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 147, 147, 32)      1568
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 70, 70, 64)        32832
#
#  max_pooling2d_1 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       131200
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 4,393,313
# Trainable params: 4,393,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = cnn.fit( train_data, epochs=50, verbose=1, validation_data=valid_data )

# Previous tests:
# 1. Epochs = 20 >>> loss: 0.0623 - accuracy: 0.9791 - val_loss: 0.0440 - val_accuracy: 0.9825

# 3. Epochs = 50 >>> loss: 0.0297 - accuracy: 0.9879 - val_loss: 0.0362 - val_accuracy: 0.987

# With only 20 epochs, the model got an accuracy of almost 98% on both training and validation sets
# Out:
# Epoch 1/50
# 96/96 [==============================] - 33s 327ms/step - loss: 0.6359 - accuracy: 0.6310 - val_loss: 0.3218 - val_accuracy: 0.8625
# Epoch 2/50
# 96/96 [==============================] - 31s 318ms/step - loss: 0.3599 - accuracy: 0.8520 - val_loss: 0.4153 - val_accuracy: 0.8025
# Epoch 3/50
# 96/96 [==============================] - 31s 319ms/step - loss: 0.2959 - accuracy: 0.8695 - val_loss: 0.1502 - val_accuracy: 0.9425
# Epoch 4/50
# 96/96 [==============================] - 31s 318ms/step - loss: 0.3908 - accuracy: 0.8209 - val_loss: 0.1054 - val_accuracy: 0.9575
# Epoch 5/50
# 96/96 [==============================] - 31s 318ms/step - loss: 0.1570 - accuracy: 0.9340 - val_loss: 0.1464 - val_accuracy: 0.9475
# Epoch 6/50
# 96/96 [==============================] - 30s 316ms/step - loss: 0.1377 - accuracy: 0.9432 - val_loss: 0.1038 - val_accuracy: 0.9625
# Epoch 7/50
# 96/96 [==============================] - 31s 320ms/step - loss: 0.1114 - accuracy: 0.9573 - val_loss: 0.1097 - val_accuracy: 0.9575
# Epoch 8/50
# 96/96 [==============================] - 31s 319ms/step - loss: 0.0973 - accuracy: 0.9631 - val_loss: 0.0996 - val_accuracy: 0.9600
# Epoch 9/50
# 96/96 [==============================] - 30s 317ms/step - loss: 0.1134 - accuracy: 0.9628 - val_loss: 0.0654 - val_accuracy: 0.9825
# Epoch 10/50
# 96/96 [==============================] - 30s 313ms/step - loss: 0.0769 - accuracy: 0.9716 - val_loss: 0.0862 - val_accuracy: 0.9700
# Epoch 11/50
# 96/96 [==============================] - 30s 315ms/step - loss: 0.0798 - accuracy: 0.9730 - val_loss: 0.0844 - val_accuracy: 0.9825
# Epoch 12/50
# 96/96 [==============================] - 30s 312ms/step - loss: 0.1073 - accuracy: 0.9594 - val_loss: 0.0753 - val_accuracy: 0.9725
# 96/96 [==============================] - 31s 319ms/step - loss: 0.0499 - accuracy: 0.9833 - val_loss: 0.0486 - val_accuracy: 0.9875
# Epoch 33/50
# 96/96 [==============================] - 31s 320ms/step - loss: 0.0571 - accuracy: 0.9788 - val_loss: 0.0839 - val_accuracy: 0.9800
# Epoch 34/50
# 96/96 [==============================] - 31s 321ms/step - loss: 0.0502 - accuracy: 0.9826 - val_loss: 0.0392 - val_accuracy: 0.9900
# Epoch 35/50
# 96/96 [==============================] - 30s 317ms/step - loss: 0.0354 - accuracy: 0.9870 - val_loss: 0.0392 - val_accuracy: 0.9825
# Epoch 36/50
# 96/96 [==============================] - 31s 318ms/step - loss: 0.0522 - accuracy: 0.9813 - val_loss: 0.0453 - val_accuracy: 0.9775
# Epoch 37/50
# 96/96 [==============================] - 30s 316ms/step - loss: 0.0471 - accuracy: 0.9797 - val_loss: 0.0415 - val_accuracy: 0.9875
# Epoch 38/50
# 96/96 [==============================] - 30s 316ms/step - loss: 0.0400 - accuracy: 0.9857 - val_loss: 0.0998 - val_accuracy: 0.9625
# Epoch 39/50
# 96/96 [==============================] - 30s 311ms/step - loss: 0.0496 - accuracy: 0.9805 - val_loss: 0.0310 - val_accuracy: 0.9875
# Epoch 40/50
# 96/96 [==============================] - 30s 311ms/step - loss: 0.0345 - accuracy: 0.9888 - val_loss: 0.0327 - val_accuracy: 0.9900
# Epoch 41/50
# 96/96 [==============================] - 30s 308ms/step - loss: 0.0293 - accuracy: 0.9901 - val_loss: 0.0796 - val_accuracy: 0.9675
# Epoch 42/50
# 96/96 [==============================] - 30s 312ms/step - loss: 0.0555 - accuracy: 0.9812 - val_loss: 0.0376 - val_accuracy: 0.9850
# Epoch 43/50
# 96/96 [==============================] - 30s 309ms/step - loss: 0.0307 - accuracy: 0.9892 - val_loss: 0.0380 - val_accuracy: 0.9875
# Epoch 44/50
# 96/96 [==============================] - 30s 311ms/step - loss: 0.0428 - accuracy: 0.9868 - val_loss: 0.0391 - val_accuracy: 0.9850
# Epoch 45/50
# 96/96 [==============================] - 30s 309ms/step - loss: 0.0562 - accuracy: 0.9757 - val_loss: 0.0152 - val_accuracy: 0.9975
# Epoch 46/50
# 96/96 [==============================] - 30s 311ms/step - loss: 0.0308 - accuracy: 0.9889 - val_loss: 0.0199 - val_accuracy: 0.9950
# Epoch 47/50
# 96/96 [==============================] - 30s 308ms/step - loss: 0.0304 - accuracy: 0.9874 - val_loss: 0.0275 - val_accuracy: 0.9925
# Epoch 48/50
# 96/96 [==============================] - 30s 310ms/step - loss: 0.0351 - accuracy: 0.9881 - val_loss: 0.0277 - val_accuracy: 0.9925
# Epoch 49/50
# 96/96 [==============================] - 30s 309ms/step - loss: 0.0395 - accuracy: 0.9867 - val_loss: 0.0222 - val_accuracy: 0.9925
# Epoch 50/50
# 96/96 [==============================] - 29s 306ms/step - loss: 0.0297 - accuracy: 0.9879 - val_loss: 0.0362 - val_accuracy: 0.9875

# %%
# Loss Curves
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Accuracy curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'g', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
