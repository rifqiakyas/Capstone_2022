# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2
import pathlib

# %%
import os
base_dir = 'C:\Sem 5\Studi Independen\Machine Learning\CapstoneProject\datasetBersih'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,           # normalisasi data                
                    ) 
test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=64,
                                                    target_size=(224, 224),
                                                    class_mode='categorical',
                                                    color_mode= 'rgb', 
                                                    shuffle= True
                                                    )
test_generator = test_datagen.flow_from_directory(validation_dir,
                                                  batch_size=64,
                                                  target_size=(224, 224),
                                                  class_mode='categorical',
                                                  color_mode= 'rgb', 
                                                  shuffle= True
                                                  )
# Out:
# Found 11110 images belonging to 11 classes.
# Found 2783 images belonging to 11 classes.

# %%
class_dict=train_generator.class_indices
classes=list(class_dict.keys())
print ('LIST OF CLASSES ', classes)
print ('CLASS DICTIONARY ',class_dict)
number_of_classes=len(classes) # this is the number of neurons in your top layer of the model
print ('Number of classes = ', number_of_classes)
# Out:
# LIST OF CLASSES  ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_Yellow_Leaf_Curl_Virus', 'Tomato_mosaic_virus', 'healthy', 'powdery_mildew']
# CLASS DICTIONARY  {'Bacterial_spot': 0, 'Early_blight': 1, 'Late_blight': 2, 'Leaf_Mold': 3, 'Septoria_leaf_spot': 4, 'Spider_mites Two-spotted_spider_mite': 5, 'Target_Spot': 6, 'Tomato_Yellow_Leaf_Curl_Virus': 7, 'Tomato_mosaic_virus': 8, 'healthy': 9, 'powdery_mildew': 10}
# Number of classes =  11

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),                           # 3 layer konvolusi
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),                                                      # layer input untuk deep learning neural network
    
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(11, activation= 'softmax')    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 4,817,995
# Trainable params: 4,817,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer ='Adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
class TestCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > 0.92 and logs.get('val_accuracy') > 0.92):
            print("\nAkurasi telah mencapai >90%!") 
            self.model.stop_training = True 
callbacks = TestCallback()

# %%
history=model.fit(
      train_generator,
      steps_per_epoch=4,                    
      epochs=50,                            
      validation_data=test_generator,       
      verbose=2,
      validation_steps=4,             
      callbacks = [callbacks]
      )
# Out:
# Epoch 1/50
# 4/4 - 17s - loss: 2.4093 - accuracy: 0.1016 - val_loss: 2.3983 - val_accuracy: 0.0898 - 17s/epoch - 4s/step
# Epoch 2/50
# 4/4 - 15s - loss: 2.3885 - accuracy: 0.0781 - val_loss: 2.3206 - val_accuracy: 0.2539 - 15s/epoch - 4s/step
# Epoch 3/50
# 4/4 - 15s - loss: 2.2349 - accuracy: 0.2266 - val_loss: 2.1335 - val_accuracy: 0.2617 - 15s/epoch - 4s/step
# Epoch 4/50
# 4/4 - 15s - loss: 2.1287 - accuracy: 0.1992 - val_loss: 2.0613 - val_accuracy: 0.2734 - 15s/epoch - 4s/step
# Epoch 5/50
# 4/4 - 15s - loss: 1.9466 - accuracy: 0.3555 - val_loss: 1.9436 - val_accuracy: 0.3438 - 15s/epoch - 4s/step
# Epoch 6/50
# 4/4 - 15s - loss: 1.9283 - accuracy: 0.3242 - val_loss: 1.7308 - val_accuracy: 0.3828 - 15s/epoch - 4s/step
# Epoch 7/50
# 4/4 - 15s - loss: 1.7311 - accuracy: 0.3594 - val_loss: 1.5014 - val_accuracy: 0.5430 - 15s/epoch - 4s/step
# Epoch 8/50
# 4/4 - 15s - loss: 1.5532 - accuracy: 0.4375 - val_loss: 1.4548 - val_accuracy: 0.4766 - 15s/epoch - 4s/step
# Epoch 9/50
# 4/4 - 15s - loss: 1.5269 - accuracy: 0.4766 - val_loss: 1.4003 - val_accuracy: 0.4727 - 15s/epoch - 4s/step
# Epoch 10/50
# 4/4 - 15s - loss: 1.4224 - accuracy: 0.4688 - val_loss: 1.3187 - val_accuracy: 0.5547 - 15s/epoch - 4s/step
# Epoch 11/50
# 4/4 - 15s - loss: 1.3176 - accuracy: 0.5547 - val_loss: 1.2777 - val_accuracy: 0.5156 - 15s/epoch - 4s/step
# Epoch 12/50
# 4/4 - 15s - loss: 1.3940 - accuracy: 0.5273 - val_loss: 1.2891 - val_accuracy: 0.5586 - 15s/epoch - 4s/step
# Epoch 13/50
# 4/4 - 15s - loss: 1.1669 - accuracy: 0.6055 - val_loss: 1.2744 - val_accuracy: 0.5195 - 15s/epoch - 4s/step
# Epoch 14/50
# 4/4 - 14s - loss: 1.3057 - accuracy: 0.5391 - val_loss: 1.1647 - val_accuracy: 0.5938 - 14s/epoch - 4s/step
# Epoch 15/50
# 4/4 - 15s - loss: 1.1641 - accuracy: 0.5859 - val_loss: 1.3457 - val_accuracy: 0.4922 - 15s/epoch - 4s/step
# Epoch 16/50
# 4/4 - 15s - loss: 1.1770 - accuracy: 0.5664 - val_loss: 1.0641 - val_accuracy: 0.6406 - 15s/epoch - 4s/step
# Epoch 17/50
# 4/4 - 14s - loss: 1.2227 - accuracy: 0.5469 - val_loss: 1.2797 - val_accuracy: 0.5703 - 14s/epoch - 4s/step
# Epoch 18/50
# 4/4 - 15s - loss: 1.1365 - accuracy: 0.5820 - val_loss: 1.1539 - val_accuracy: 0.5820 - 15s/epoch - 4s/step
# Epoch 19/50
# 4/4 - 15s - loss: 1.0640 - accuracy: 0.6328 - val_loss: 1.0929 - val_accuracy: 0.6367 - 15s/epoch - 4s/step
# Epoch 20/50
# 4/4 - 15s - loss: 0.9844 - accuracy: 0.7070 - val_loss: 1.0184 - val_accuracy: 0.6523 - 15s/epoch - 4s/step
# Epoch 21/50
# 4/4 - 15s - loss: 1.0233 - accuracy: 0.6250 - val_loss: 1.1311 - val_accuracy: 0.5586 - 15s/epoch - 4s/step
# Epoch 22/50
# 4/4 - 15s - loss: 1.0938 - accuracy: 0.6250 - val_loss: 1.1044 - val_accuracy: 0.6523 - 15s/epoch - 4s/step
# Epoch 23/50
# 4/4 - 15s - loss: 1.0655 - accuracy: 0.6445 - val_loss: 1.1386 - val_accuracy: 0.6367 - 15s/epoch - 4s/step
# Epoch 24/50
# 4/4 - 14s - loss: 1.1026 - accuracy: 0.6348 - val_loss: 1.0620 - val_accuracy: 0.6719 - 14s/epoch - 3s/step
# Epoch 25/50
# 4/4 - 15s - loss: 0.9500 - accuracy: 0.6484 - val_loss: 1.1463 - val_accuracy: 0.6289 - 15s/epoch - 4s/step
# Epoch 26/50
# 4/4 - 15s - loss: 1.0157 - accuracy: 0.6562 - val_loss: 0.8939 - val_accuracy: 0.7109 - 15s/epoch - 4s/step
# Epoch 27/50
# 4/4 - 14s - loss: 0.9798 - accuracy: 0.6836 - val_loss: 0.9003 - val_accuracy: 0.6914 - 14s/epoch - 4s/step
# Epoch 28/50
# 4/4 - 14s - loss: 1.0786 - accuracy: 0.6367 - val_loss: 1.0075 - val_accuracy: 0.6641 - 14s/epoch - 3s/step
# Epoch 29/50
# 4/4 - 14s - loss: 0.8553 - accuracy: 0.7070 - val_loss: 1.0466 - val_accuracy: 0.6719 - 14s/epoch - 4s/step
# Epoch 30/50
# 4/4 - 15s - loss: 0.8276 - accuracy: 0.7383 - val_loss: 0.8851 - val_accuracy: 0.7266 - 15s/epoch - 4s/step
# Epoch 31/50
# 4/4 - 15s - loss: 0.9236 - accuracy: 0.6758 - val_loss: 0.9998 - val_accuracy: 0.6484 - 15s/epoch - 4s/step
# Epoch 32/50
# 4/4 - 15s - loss: 0.8671 - accuracy: 0.7031 - val_loss: 0.8600 - val_accuracy: 0.7422 - 15s/epoch - 4s/step
# Epoch 33/50
# 4/4 - 15s - loss: 0.8764 - accuracy: 0.6992 - val_loss: 0.9704 - val_accuracy: 0.7070 - 15s/epoch - 4s/step
# Epoch 34/50
# 4/4 - 15s - loss: 0.9218 - accuracy: 0.6992 - val_loss: 0.8835 - val_accuracy: 0.6797 - 15s/epoch - 4s/step
# Epoch 35/50
# 4/4 - 15s - loss: 0.9432 - accuracy: 0.6680 - val_loss: 0.8198 - val_accuracy: 0.7109 - 15s/epoch - 4s/step
# Epoch 36/50
# 4/4 - 14s - loss: 0.9129 - accuracy: 0.6836 - val_loss: 0.9202 - val_accuracy: 0.6875 - 14s/epoch - 3s/step
# Epoch 37/50
# 4/4 - 14s - loss: 0.9102 - accuracy: 0.7188 - val_loss: 0.8310 - val_accuracy: 0.7188 - 14s/epoch - 3s/step
# Epoch 38/50
# 4/4 - 15s - loss: 0.9696 - accuracy: 0.6641 - val_loss: 0.8705 - val_accuracy: 0.7188 - 15s/epoch - 4s/step
# Epoch 39/50
# 4/4 - 14s - loss: 0.8118 - accuracy: 0.7578 - val_loss: 0.9136 - val_accuracy: 0.7070 - 14s/epoch - 4s/step
# Epoch 40/50
# 4/4 - 14s - loss: 0.8555 - accuracy: 0.7266 - val_loss: 0.9822 - val_accuracy: 0.6875 - 14s/epoch - 4s/step
# Epoch 41/50
# 4/4 - 15s - loss: 0.8019 - accuracy: 0.7383 - val_loss: 0.7859 - val_accuracy: 0.7188 - 15s/epoch - 4s/step
# Epoch 42/50
# 4/4 - 15s - loss: 0.8257 - accuracy: 0.7188 - val_loss: 0.9395 - val_accuracy: 0.6602 - 15s/epoch - 4s/step
# Epoch 43/50
# 4/4 - 15s - loss: 0.8306 - accuracy: 0.7461 - val_loss: 0.7846 - val_accuracy: 0.7500 - 15s/epoch - 4s/step
# Epoch 44/50
# 4/4 - 14s - loss: 0.7644 - accuracy: 0.7383 - val_loss: 0.8683 - val_accuracy: 0.7148 - 14s/epoch - 3s/step
# Epoch 45/50
# 4/4 - 14s - loss: 0.7106 - accuracy: 0.7891 - val_loss: 0.7623 - val_accuracy: 0.7500 - 14s/epoch - 4s/step
# Epoch 46/50
# 4/4 - 15s - loss: 0.6971 - accuracy: 0.7500 - val_loss: 0.8629 - val_accuracy: 0.7148 - 15s/epoch - 4s/step
# Epoch 47/50
# 4/4 - 15s - loss: 0.8444 - accuracy: 0.7617 - val_loss: 0.7133 - val_accuracy: 0.7656 - 15s/epoch - 4s/step
# Epoch 48/50
# 4/4 - 15s - loss: 0.7551 - accuracy: 0.7695 - val_loss: 0.8670 - val_accuracy: 0.7266 - 15s/epoch - 4s/step
# Epoch 49/50
# 4/4 - 14s - loss: 0.7689 - accuracy: 0.7617 - val_loss: 0.7991 - val_accuracy: 0.7422 - 14s/epoch - 4s/step
# Epoch 50/50
# 4/4 - 14s - loss: 0.7346 - accuracy: 0.7383 - val_loss: 0.8200 - val_accuracy: 0.7305 - 14s/epoch - 4s/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
history.predict
