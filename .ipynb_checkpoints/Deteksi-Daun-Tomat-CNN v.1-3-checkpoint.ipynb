# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2
import pathlib

# %%
import splitfolders

splitfolders.ratio('C:\Sem 5\Studi Independen\Machine Learning\Tomato\daunTomatGab',
                    output='C:\Sem 5\Studi Independen\Machine Learning\Tomato\Dataset',
                    seed=1337,
                    ratio=(.6, .4))

# %%
import os
base_dir = 'C:\Sem 5\Studi Independen\Machine Learning\CapstoneProject\datasetBersih'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,           # normalisasi data                
                    ) 
test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=64,
                                                    target_size=(224, 224),
                                                    class_mode='categorical',
                                                    color_mode= 'rgb', 
                                                    shuffle= True
                                                    )
test_generator = test_datagen.flow_from_directory(validation_dir,
                                                  batch_size=64,
                                                  target_size=(224, 224),
                                                  class_mode='categorical',
                                                  color_mode= 'rgb', 
                                                  shuffle= True
                                                  )
# Out:
# Found 11110 images belonging to 11 classes.
# Found 2783 images belonging to 11 classes.

# %%
class_dict=train_generator.class_indices
classes=list(class_dict.keys())
print ('LIST OF CLASSES ', classes)
print ('CLASS DICTIONARY ',class_dict)
number_of_classes=len(classes) # this is the number of neurons in your top layer of the model
print ('Number of classes = ', number_of_classes)
# Out:
# LIST OF CLASSES  ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_Yellow_Leaf_Curl_Virus', 'Tomato_mosaic_virus', 'healthy', 'powdery_mildew']
# CLASS DICTIONARY  {'Bacterial_spot': 0, 'Early_blight': 1, 'Late_blight': 2, 'Leaf_Mold': 3, 'Septoria_leaf_spot': 4, 'Spider_mites Two-spotted_spider_mite': 5, 'Target_Spot': 6, 'Tomato_Yellow_Leaf_Curl_Virus': 7, 'Tomato_mosaic_virus': 8, 'healthy': 9, 'powdery_mildew': 10}
# Number of classes =  11

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),                           # 3 layer konvolusi
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),                                                      # layer input untuk deep learning neural network
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'), 
    tf.keras.layers.Dense(11, activation= 'softmax')    
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 222, 222, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 111, 111, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 52, 52, 32)        9248
#
#  max_pooling2d_5 (MaxPooling  (None, 26, 26, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 21632)             0
#
#  dropout_2 (Dropout)         (None, 21632)             0
#
#  dense_3 (Dense)             (None, 512)               11076096
#
#  dense_4 (Dense)             (None, 128)               65664
#
#  dense_5 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 11,157,515
# Trainable params: 11,157,515
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer ='Adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
class TestCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > 0.92 and logs.get('val_accuracy') > 0.92):
            print("\nAkurasi telah mencapai >90%!") 
            self.model.stop_training = True 
callbacks = TestCallback()

# %%
history=model.fit(
      train_generator,
      steps_per_epoch=4,                    
      epochs=25,                            
      validation_data=test_generator,       
      verbose=2,
      validation_steps=4,             
      callbacks = [callbacks]
      )
# Out:
# Epoch 1/25
# 4/4 - 8s - loss: 2.4210 - accuracy: 0.1133 - val_loss: 2.3329 - val_accuracy: 0.2305 - 8s/epoch - 2s/step
# Epoch 2/25
# 4/4 - 5s - loss: 2.3397 - accuracy: 0.1445 - val_loss: 2.2383 - val_accuracy: 0.1914 - 5s/epoch - 1s/step
# Epoch 3/25
# 4/4 - 7s - loss: 2.0784 - accuracy: 0.2891 - val_loss: 2.0187 - val_accuracy: 0.3438 - 7s/epoch - 2s/step
# Epoch 4/25
# 4/4 - 6s - loss: 1.9057 - accuracy: 0.3398 - val_loss: 1.9533 - val_accuracy: 0.2734 - 6s/epoch - 1s/step
# Epoch 5/25
# 4/4 - 6s - loss: 1.9099 - accuracy: 0.3320 - val_loss: 1.5993 - val_accuracy: 0.4648 - 6s/epoch - 2s/step
# Epoch 6/25
# 4/4 - 5s - loss: 1.7304 - accuracy: 0.3696 - val_loss: 1.8365 - val_accuracy: 0.4141 - 5s/epoch - 1s/step
# Epoch 7/25
# 4/4 - 6s - loss: 1.6670 - accuracy: 0.4570 - val_loss: 1.6669 - val_accuracy: 0.4141 - 6s/epoch - 2s/step
# Epoch 8/25
# 4/4 - 6s - loss: 1.5717 - accuracy: 0.4570 - val_loss: 1.3462 - val_accuracy: 0.5586 - 6s/epoch - 2s/step
# Epoch 9/25
# 4/4 - 6s - loss: 1.5315 - accuracy: 0.4961 - val_loss: 1.4067 - val_accuracy: 0.4805 - 6s/epoch - 1s/step
# Epoch 10/25
# 4/4 - 7s - loss: 1.4542 - accuracy: 0.4922 - val_loss: 1.4916 - val_accuracy: 0.4805 - 7s/epoch - 2s/step
# Epoch 11/25
# 4/4 - 5s - loss: 1.4811 - accuracy: 0.5117 - val_loss: 1.4308 - val_accuracy: 0.5430 - 5s/epoch - 1s/step
# Epoch 12/25
# 4/4 - 7s - loss: 1.4166 - accuracy: 0.5234 - val_loss: 1.3586 - val_accuracy: 0.5195 - 7s/epoch - 2s/step
# Epoch 13/25
# 4/4 - 5s - loss: 1.3945 - accuracy: 0.5430 - val_loss: 1.2586 - val_accuracy: 0.6016 - 5s/epoch - 1s/step
# Epoch 14/25
# 4/4 - 4s - loss: 1.1752 - accuracy: 0.6016 - val_loss: 1.0180 - val_accuracy: 0.6875 - 4s/epoch - 1s/step
# Epoch 15/25
# 4/4 - 4s - loss: 1.0714 - accuracy: 0.6367 - val_loss: 1.0292 - val_accuracy: 0.6133 - 4s/epoch - 992ms/step
# Epoch 16/25
# 4/4 - 4s - loss: 1.1143 - accuracy: 0.5938 - val_loss: 1.1069 - val_accuracy: 0.6094 - 4s/epoch - 999ms/step
# Epoch 17/25
# 4/4 - 4s - loss: 1.1433 - accuracy: 0.6016 - val_loss: 1.1215 - val_accuracy: 0.6172 - 4s/epoch - 995ms/step
# Epoch 18/25
# 4/4 - 4s - loss: 1.0805 - accuracy: 0.6211 - val_loss: 0.9084 - val_accuracy: 0.6641 - 4s/epoch - 1s/step
# Epoch 19/25
# 4/4 - 4s - loss: 0.9372 - accuracy: 0.6484 - val_loss: 1.0352 - val_accuracy: 0.6250 - 4s/epoch - 984ms/step
# Epoch 20/25
# 4/4 - 4s - loss: 1.0460 - accuracy: 0.6445 - val_loss: 0.9701 - val_accuracy: 0.6641 - 4s/epoch - 983ms/step
# Epoch 21/25
# 4/4 - 4s - loss: 1.1020 - accuracy: 0.6367 - val_loss: 1.0215 - val_accuracy: 0.6641 - 4s/epoch - 997ms/step
# Epoch 22/25
# 4/4 - 4s - loss: 0.9710 - accuracy: 0.6562 - val_loss: 0.9503 - val_accuracy: 0.6641 - 4s/epoch - 990ms/step
# Epoch 23/25
# 4/4 - 4s - loss: 0.9386 - accuracy: 0.7227 - val_loss: 1.0353 - val_accuracy: 0.6484 - 4s/epoch - 1s/step
# Epoch 24/25
# 4/4 - 4s - loss: 1.0353 - accuracy: 0.6367 - val_loss: 1.1201 - val_accuracy: 0.5664 - 4s/epoch - 983ms/step
# Epoch 25/25
# 4/4 - 4s - loss: 0.8705 - accuracy: 0.7070 - val_loss: 0.9398 - val_accuracy: 0.6875 - 4s/epoch - 1s/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
