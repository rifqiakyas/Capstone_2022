# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Input
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import ResNet152V2
import pathlib

# %%
import os
base_dir = 'C:\Sem 5\Studi Independen\Machine Learning\CapstoneProject\Dataset'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'val')

# %%
train_datagen = ImageDataGenerator(
                    rescale=1./255,           # normalisasi data                
                    ) 
test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=64,
                                                    target_size=(224, 224),
                                                    class_mode='categorical',
                                                    color_mode= 'rgb', 
                                                    shuffle= True
                                                    )
test_generator = test_datagen.flow_from_directory(validation_dir,
                                                  batch_size=64,
                                                  target_size=(224, 224),
                                                  class_mode='categorical',
                                                  color_mode= 'rgb', 
                                                  shuffle= True
                                                  )
# Out:
# Found 25430 images belonging to 11 classes.
# Found 6363 images belonging to 11 classes.

# %%
class_dict=train_generator.class_indices
classes=list(class_dict.keys())
print ('LIST OF CLASSES ', classes)
print ('CLASS DICTIONARY ',class_dict)
number_of_classes=len(classes) # this is the number of neurons in your top layer of the model
print ('Number of classes = ', number_of_classes)
# Out:
# LIST OF CLASSES  ['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_Yellow_Leaf_Curl_Virus', 'Tomato_mosaic_virus', 'healthy', 'powdery_mildew']
# CLASS DICTIONARY  {'Bacterial_spot': 0, 'Early_blight': 1, 'Late_blight': 2, 'Leaf_Mold': 3, 'Septoria_leaf_spot': 4, 'Spider_mites Two-spotted_spider_mite': 5, 'Target_Spot': 6, 'Tomato_Yellow_Leaf_Curl_Virus': 7, 'Tomato_mosaic_virus': 8, 'healthy': 9, 'powdery_mildew': 10}
# Number of classes =  11

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),                           # 3 layer konvolusi
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),                                                      # layer input untuk deep learning neural network
    
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(11, activation= 'softmax')    
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 512)               4719104
#
#  dense_1 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 4,817,995
# Trainable params: 4,817,995
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer ='Adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
class TestCallback(tf.keras.callbacks.Callback): 
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('accuracy') > 0.92 and logs.get('val_accuracy') > 0.92):
            print("\nAkurasi telah mencapai >90%!") 
            self.model.stop_training = True 
callbacks = TestCallback()

# %%
history=model.fit(
      train_generator,
      steps_per_epoch=4,                    
      epochs=50,                            
      validation_data=test_generator,       
      verbose=2,
      validation_steps=4,             
      callbacks = [callbacks]
      )
# Out:
# Epoch 1/50
# 4/4 - 19s - loss: 2.7463 - accuracy: 0.1016 - val_loss: 2.3929 - val_accuracy: 0.1211 - 19s/epoch - 5s/step
# Epoch 2/50
# 4/4 - 16s - loss: 2.3891 - accuracy: 0.1172 - val_loss: 2.3680 - val_accuracy: 0.1172 - 16s/epoch - 4s/step
# Epoch 3/50
# 4/4 - 16s - loss: 2.3477 - accuracy: 0.1758 - val_loss: 2.4059 - val_accuracy: 0.0820 - 16s/epoch - 4s/step
# Epoch 4/50
# 4/4 - 16s - loss: 2.3371 - accuracy: 0.1445 - val_loss: 2.3469 - val_accuracy: 0.1523 - 16s/epoch - 4s/step
# Epoch 5/50
# 4/4 - 15s - loss: 2.3545 - accuracy: 0.1406 - val_loss: 2.3573 - val_accuracy: 0.1133 - 15s/epoch - 4s/step
# Epoch 6/50
# 4/4 - 16s - loss: 2.3501 - accuracy: 0.1250 - val_loss: 2.3587 - val_accuracy: 0.1172 - 16s/epoch - 4s/step
# Epoch 7/50
# 4/4 - 15s - loss: 2.3156 - accuracy: 0.1641 - val_loss: 2.2534 - val_accuracy: 0.1562 - 15s/epoch - 4s/step
# Epoch 8/50
# 4/4 - 15s - loss: 2.2018 - accuracy: 0.2070 - val_loss: 2.1839 - val_accuracy: 0.2578 - 15s/epoch - 4s/step
# Epoch 9/50
# 4/4 - 16s - loss: 2.1282 - accuracy: 0.2266 - val_loss: 2.0957 - val_accuracy: 0.2227 - 16s/epoch - 4s/step
# Epoch 10/50
# 4/4 - 16s - loss: 2.0636 - accuracy: 0.2188 - val_loss: 1.9698 - val_accuracy: 0.2734 - 16s/epoch - 4s/step
# Epoch 11/50
# 4/4 - 16s - loss: 2.0174 - accuracy: 0.2422 - val_loss: 2.0229 - val_accuracy: 0.2773 - 16s/epoch - 4s/step
# Epoch 12/50
# 4/4 - 16s - loss: 1.9485 - accuracy: 0.3047 - val_loss: 2.0115 - val_accuracy: 0.2773 - 16s/epoch - 4s/step
# Epoch 13/50
# 4/4 - 15s - loss: 1.8530 - accuracy: 0.3672 - val_loss: 1.7551 - val_accuracy: 0.4141 - 15s/epoch - 4s/step
# Epoch 14/50
# 4/4 - 16s - loss: 1.6448 - accuracy: 0.4180 - val_loss: 2.1431 - val_accuracy: 0.3008 - 16s/epoch - 4s/step
# Epoch 15/50
# 4/4 - 15s - loss: 1.8428 - accuracy: 0.3398 - val_loss: 1.6803 - val_accuracy: 0.4453 - 15s/epoch - 4s/step
# Epoch 16/50
# 4/4 - 16s - loss: 1.6739 - accuracy: 0.4297 - val_loss: 2.0665 - val_accuracy: 0.2734 - 16s/epoch - 4s/step
# Epoch 17/50
# 4/4 - 17s - loss: 1.8265 - accuracy: 0.3750 - val_loss: 1.5981 - val_accuracy: 0.5039 - 17s/epoch - 4s/step
# Epoch 18/50
# 4/4 - 16s - loss: 1.6325 - accuracy: 0.4258 - val_loss: 1.7481 - val_accuracy: 0.4219 - 16s/epoch - 4s/step
# Epoch 19/50
# 4/4 - 13s - loss: 1.6421 - accuracy: 0.4299 - val_loss: 1.6089 - val_accuracy: 0.4375 - 13s/epoch - 3s/step
# Epoch 20/50
# 4/4 - 16s - loss: 1.6756 - accuracy: 0.3828 - val_loss: 1.5600 - val_accuracy: 0.4492 - 16s/epoch - 4s/step
# Epoch 21/50
# 4/4 - 15s - loss: 1.4664 - accuracy: 0.4844 - val_loss: 1.4403 - val_accuracy: 0.5430 - 15s/epoch - 4s/step
# Epoch 22/50
# 4/4 - 15s - loss: 1.4368 - accuracy: 0.5117 - val_loss: 1.3416 - val_accuracy: 0.5703 - 15s/epoch - 4s/step
# Epoch 23/50
# 4/4 - 16s - loss: 1.3875 - accuracy: 0.5312 - val_loss: 1.2948 - val_accuracy: 0.5547 - 16s/epoch - 4s/step
# Epoch 24/50
# 4/4 - 15s - loss: 1.4100 - accuracy: 0.5430 - val_loss: 1.3208 - val_accuracy: 0.5664 - 15s/epoch - 4s/step
# Epoch 25/50
# 4/4 - 15s - loss: 1.4669 - accuracy: 0.4727 - val_loss: 1.4004 - val_accuracy: 0.5078 - 15s/epoch - 4s/step
# Epoch 26/50
# 4/4 - 15s - loss: 1.2455 - accuracy: 0.5625 - val_loss: 1.3495 - val_accuracy: 0.5312 - 15s/epoch - 4s/step
# Epoch 27/50
# 4/4 - 15s - loss: 1.3028 - accuracy: 0.5586 - val_loss: 1.4070 - val_accuracy: 0.5469 - 15s/epoch - 4s/step
# Epoch 28/50
# 4/4 - 16s - loss: 1.3787 - accuracy: 0.4844 - val_loss: 1.2632 - val_accuracy: 0.6055 - 16s/epoch - 4s/step
# Epoch 29/50
# 4/4 - 15s - loss: 1.2148 - accuracy: 0.6250 - val_loss: 1.1906 - val_accuracy: 0.5508 - 15s/epoch - 4s/step
# Epoch 30/50
# 4/4 - 15s - loss: 1.2103 - accuracy: 0.6055 - val_loss: 1.1577 - val_accuracy: 0.6094 - 15s/epoch - 4s/step
# Epoch 31/50
# 4/4 - 15s - loss: 1.2237 - accuracy: 0.5742 - val_loss: 1.1668 - val_accuracy: 0.6016 - 15s/epoch - 4s/step
# Epoch 32/50
# 4/4 - 15s - loss: 1.2681 - accuracy: 0.5898 - val_loss: 1.2019 - val_accuracy: 0.5547 - 15s/epoch - 4s/step
# Epoch 33/50
# 4/4 - 15s - loss: 1.0394 - accuracy: 0.6719 - val_loss: 1.2886 - val_accuracy: 0.5469 - 15s/epoch - 4s/step
# Epoch 34/50
# 4/4 - 15s - loss: 1.2152 - accuracy: 0.5664 - val_loss: 1.1309 - val_accuracy: 0.6172 - 15s/epoch - 4s/step
# Epoch 35/50
# 4/4 - 16s - loss: 1.1760 - accuracy: 0.6016 - val_loss: 1.2812 - val_accuracy: 0.5547 - 16s/epoch - 4s/step
# Epoch 36/50
# 4/4 - 15s - loss: 1.2385 - accuracy: 0.6016 - val_loss: 1.2270 - val_accuracy: 0.5586 - 15s/epoch - 4s/step
# Epoch 37/50
# 4/4 - 15s - loss: 1.1930 - accuracy: 0.6016 - val_loss: 1.1040 - val_accuracy: 0.6680 - 15s/epoch - 4s/step
# Epoch 38/50
# 4/4 - 15s - loss: 1.0633 - accuracy: 0.6641 - val_loss: 1.0605 - val_accuracy: 0.6250 - 15s/epoch - 4s/step
# Epoch 39/50
# 4/4 - 15s - loss: 1.1654 - accuracy: 0.6367 - val_loss: 1.0130 - val_accuracy: 0.6836 - 15s/epoch - 4s/step
# Epoch 40/50
# 4/4 - 15s - loss: 1.3183 - accuracy: 0.5312 - val_loss: 1.1799 - val_accuracy: 0.5977 - 15s/epoch - 4s/step
# Epoch 41/50
# 4/4 - 15s - loss: 1.0185 - accuracy: 0.6523 - val_loss: 1.0080 - val_accuracy: 0.6680 - 15s/epoch - 4s/step
# Epoch 42/50
# 4/4 - 15s - loss: 0.9967 - accuracy: 0.6875 - val_loss: 0.9836 - val_accuracy: 0.6484 - 15s/epoch - 4s/step
# Epoch 43/50
# 4/4 - 16s - loss: 1.0863 - accuracy: 0.5742 - val_loss: 1.0441 - val_accuracy: 0.6445 - 16s/epoch - 4s/step
# Epoch 44/50
# 4/4 - 15s - loss: 0.9366 - accuracy: 0.6797 - val_loss: 0.8774 - val_accuracy: 0.7227 - 15s/epoch - 4s/step
# Epoch 45/50
# 4/4 - 15s - loss: 1.0266 - accuracy: 0.6484 - val_loss: 1.0572 - val_accuracy: 0.5977 - 15s/epoch - 4s/step
# Epoch 46/50
# 4/4 - 16s - loss: 0.9907 - accuracy: 0.6914 - val_loss: 0.8824 - val_accuracy: 0.6875 - 16s/epoch - 4s/step
# Epoch 47/50
# 4/4 - 15s - loss: 0.8466 - accuracy: 0.7266 - val_loss: 0.9684 - val_accuracy: 0.6367 - 15s/epoch - 4s/step
# Epoch 48/50
# 4/4 - 15s - loss: 0.9811 - accuracy: 0.6719 - val_loss: 1.0958 - val_accuracy: 0.6055 - 15s/epoch - 4s/step
# Epoch 49/50
# 4/4 - 15s - loss: 1.0053 - accuracy: 0.6562 - val_loss: 1.1566 - val_accuracy: 0.5820 - 15s/epoch - 4s/step
# Epoch 50/50
# 4/4 - 15s - loss: 1.1478 - accuracy: 0.5664 - val_loss: 1.1847 - val_accuracy: 0.5977 - 15s/epoch - 4s/step

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Model')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
